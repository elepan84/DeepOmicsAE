# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import silhouette_score
import seaborn as sns
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, losses
from sklearn.feature_selection import SelectKBest, f_classif
import random
import warnings
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
from collections import Counter
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import csv
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from F02_autoencoder_model_optimization import * 
RANDOM_STATE = 55 ## We will pass it to every sklearn call so we ensure reproducibility

# %%
# Load the datasets using pandas
df = pd.read_csv("M01_output_data.csv")

# %%
df.shape
# Out:
# (142, 7096)

# %%
df.iloc[:, :]
# Out:
#      VAMP1|P23763  TXNDC12|O95881  PDHX|O00330  APIP|Q96GX9  CIAO1|O76071  \
# 0       -0.207101       -0.019232    -0.205116     0.373932     -0.000012
# 1        0.475842       -0.157368     0.089179    -0.195295      0.016843
# 2       -0.098888       -0.014990     0.011931     0.798387      0.035024
# 3        0.181075        0.018210    -0.139065     0.442624     -0.017682
# 4       -0.039547        0.444358    -0.148357    -0.026292     -0.078914
# ..            ...             ...          ...          ...           ...
# 137     -0.351330       -0.014922     0.035721     0.778084     -0.083676
# 138     -0.113950        0.017336    -0.167515    -0.201845      0.001335
# 139      0.011628       -0.062107     0.017524    -0.025587      0.013412
# 140      0.164222        0.060732    -0.196816     0.473578     -0.014342
# 141     -0.056616        0.030180     0.090754     0.222416      0.016382
#
#      NNT|Q13423  KIF3B|O15066  ULK1|O75385  MEF2C|Q06413  MT3|P25713  ...  \
# 0     -0.023599      0.008489     0.002501      0.202280   -0.278368  ...
# 1      0.246339     -0.065419     0.000896     -0.090978   -0.413591  ...
# 2      0.080013      0.126054     0.008523     -0.046719   -0.070404  ...
# 3      0.017770     -0.005218     0.015139      0.094830   -0.293929  ...
# 4     -0.189799      0.008934    -0.009613      0.216311    0.250805  ...
# ..          ...           ...          ...           ...         ...  ...
# 137    0.113673      0.090572     0.072134      0.078215   -0.087158  ...
# 138   -0.056832      0.026669     0.067057     -0.161870   -0.081069  ...
# 139    0.020739      0.001532     0.004974      0.199401    0.105402  ...
# 140   -0.152533     -0.105568     0.298644     -0.094707   -0.222687  ...
# 141    0.018233      0.046482     0.115916      0.010833   -0.107977  ...
#
#      999925855  999925884  999925936  999925948  999925981  999925982  \
# 0     0.436035   0.084535  -0.173663  -0.579595   0.139316   0.190447
# 1     0.020955  -0.075851  -0.314899   0.037763  -0.902173  -0.490832
# 2     0.372553  -0.053076  -1.813697   0.025903   0.541960  -0.041731
# 3     0.366699   0.290755   0.143212   0.308691   0.247830   0.442878
# 4     0.764707  -0.072413  -0.864451   0.613156   0.547153   0.208624
# ..         ...        ...        ...        ...        ...        ...
# 137   0.038574   0.193039   0.553562   0.475666   0.141958   0.416008
# 138   0.476318  -0.107512   0.237492  -0.140158   0.184475   0.159311
# 139  -0.144630  -0.006577   0.429558   0.043545   0.670410  -0.049898
# 140   0.005787   0.061623  -0.360994   0.462043   0.211947  -0.052957
# 141   0.151911   0.255130  -0.488378   0.617001   0.417323   0.045926
#
#          msex      educ  age_death  cogdx
# 0   -1.989986  0.450011   1.994412    1.0
# 1   -1.989986  0.797655   1.994412    4.0
# 2   -1.989986 -0.655922   0.847522    1.0
# 3    1.994412  1.646768   0.366377    4.0
# 4    1.994412  1.252641   1.994412    4.0
# ..        ...       ...        ...    ...
# 137 -1.989986 -0.399102  -0.104190    4.0
# 138 -1.989986 -0.399102   1.687836    4.0
# 139 -1.989986 -0.162850   1.994412    1.0
# 140 -1.989986  1.252641   1.436941    4.0
# 141  1.994412 -0.399102   0.069855    1.0
#
# [142 rows x 7096 columns]

# %%
cols_X_prot = slice(col_start, col_end)
cols_X_met = slice(col_start2, col_end2)
cols_clin = slice(col_start3, col_end3)
cols_X_expr = slice(col_start4, col_end4)
y_label = 'y_column_name' 
n_all_feat = cols_X_met.stop
n_all_feat
# Out:
# 6941

# %%
df_res, df_selected = model_optimization(df=df, n_all_feat=n_all_feat, cols_X_prot=cols_X_prot, cols_X_met=cols_X_met, cols_clin=cols_clin, cols_X_expr=cols_X_expr, y_label=y_label, n_comb=30)
# Out:
# 1
# Selecting features
# Extracting features
# 5/5 [==============================] - 0s 737us/step
# 5/5 [==============================] - 0s 721us/step
# 2
# Selecting features
# Extracting features
# 5/5 [==============================] - 0s 698us/step
# 5/5 [==============================] - 0s 647us/step
# 3
# Selecting features
# Extracting features
# 5/5 [==============================] - 0s 652us/step
# 5/5 [==============================] - 0s 619us/step
# 4
# Selecting features
# Extracting features
# 5/5 [==============================] - 0s 701us/step
# 5/5 [==============================] - 0s 759us/step
# 5
# Selecting features
# Extracting features
# 5/5 [==============================] - 0s 745us/step
# 5/5 [==============================] - 0s 721us/step
# 6
# Selecting features
# Extracting features
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 2ms/step
# 7
# Selecting features
# Extracting features
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 3ms/step
# 8
# Selecting features
# Extracting features
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# 9
# Selecting features
# Extracting features
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 3ms/step
# 10
# Selecting features
# Extracting features
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step

# %%
df_res_sort = df_res.sort_values(by='pca_extracted', ascending=False) ### order the dataframe with the results based on the values in the column "pca_extracted"

# %%
df_res_sort.head(20)
# Out:
#   kprot kmet latent  sil_score_initial  sil_score_final   pca_all  \
# 0   217   50      4           0.008064         0.172763  0.018733
# 4   272   55      4           0.008064         0.153286  0.018733
# 2    50   59      3           0.008064         0.127545  0.018733
# 1   161   64      3           0.008064         0.123045  0.018733
# 9  2162  135      3           0.008064         0.105852  0.018733
# 3   106   69      3           0.008064         0.094901  0.018733
# 7  2106  149      4           0.008064         0.075806  0.018733
# 8  2273  140      4           0.008064         0.069096  0.018733
# 5  2051  154      3           0.008064         0.078770  0.018733
# 6  2217  145      3           0.008064         0.094950  0.018733
#
#    pca_extracted
# 0       0.220429
# 4       0.177092
# 2       0.140479
# 1       0.139697
# 9       0.125922
# 3       0.112068
# 7       0.107299
# 8       0.106695
# 5       0.103513
# 6       0.096820

# %%
# Convert 'latent' to numeric values and multiply by a factor for better visibility on the scatter plot
df_res_sort['latent'] = pd.to_numeric(df_res_sort['latent'], errors='coerce')

# Create a scatter plot
plt.figure(figsize=(10, 8))
bubble_plot = plt.scatter(df_res_sort['kprot'], df_res_sort['kmet'], alpha=0.6,
                          s=df_res_sort['latent']*20,  # modify this factor to adjust the bubble sizes
                          c=df_res_sort['pca_extracted'],  # color based on 'pca_extracted' values
                          cmap='RdYlBu',  # choose a colormap
                          edgecolors='grey')  # adding grey border to the bubbles

# Add a color bar
cbar = plt.colorbar(bubble_plot)
cbar.set_label('pca_extracted')

plt.xlabel('kprot')
plt.ylabel('kmet')
plt.title('Bubble Plot')
plt.savefig('AE_optimization_plot.pdf', format='pdf', dpi=300)
plt.show()

# %%
# Calculate percentiles
percentiles = df_res_sort['pca_extracted'].quantile([0, 0.25, 0.5, 0.8, 1]).to_dict()

# Print percentiles
for key, value in percentiles.items():
    print(key)
    print(f'{key*100}th percentile: {value}')
    
    
percentile = percentiles[0.8]   ## assign the 80th percentile value to the variable percentile
# Out:
# 0.0
# 0.0th percentile: 0.09682004153728485
# 0.25
# 25.0th percentile: 0.10684568248689175
# 0.5
# 50.0th percentile: 0.1189948283135891
# 0.8
# 80.0th percentile: 0.14780164659023284
# 1.0
# 100.0th percentile: 0.22042860090732574

# %%
# Filter DataFrame where 'pca_extracted' > percentile
filtered_df = df_res_sort[df_res_sort['pca_extracted'] > percentile]

# %%
filtered_df
# Out:
#   kprot kmet  latent  sil_score_initial  sil_score_final   pca_all  \
# 0   217   50       4           0.008064         0.172763  0.018733
# 4   272   55       4           0.008064         0.153286  0.018733
#
#    pca_extracted
# 0       0.220429
# 4       0.177092

# %%
kprot = round(filtered_df['kprot'].mean())
kmet = round(filtered_df['kmet'].mean())
latent = round(filtered_df['latent'].mean())

# %store kprot kmet latent

print(f"Average kprot value when pca_extracted > {percentile}: {kprot}")
print(f"Average kmet value when pca_extracted > {percentile}: {kmet}")
print(f"Average latent value when pca_extracted > {percentile}: {latent}")
# Out:
# Stored 'kprot' (int)
# Stored 'kmet' (int)
# Stored 'latent' (int)
# Average kprot value when pca_extracted > 0.14780164659023284: 244
# Average kmet value when pca_extracted > 0.14780164659023284: 52
# Average latent value when pca_extracted > 0.14780164659023284: 4

# %%
s
